# %%
def errorMessage(setActual, lineaActual, valor): 
    print('ERROR')
    print('Se ha detectado un valor inexistente en el Catalogo', setActual)
    print('Revisar en el documento de datos en la linea: ', lineaActual)
    print('El valor no registrado es: ', valor)
    print('Favor de agregar el valor faltante a el catalago y volver a intentar')
    print('Ingrese ENTER para continuar')
    print('Ingrese cualquier otra tecla para salir')
    aux = input()
    if not aux:
        return True
    else: 
        sys.exit()
        
def openDataFile():
    entries = os.listdir("../Input/")
    i = 1
    for v in entries:
        print(str(i) + ". " + v)
        i = i + 1
    print("Seleccione el número del archivo: ")
    print("En caso de no tener el archivo en Input puede ingresar el directorio: ")
    aux = input()
    os.system("cls")
    if len(aux) <= 5:
        i = 1
        for v in entries:
            if aux == str(i):
                return pd.read_excel("../Catalogs//" + v), v
            i = i + 1
    else:
        return pd.read_excel(aux)
        

        
def setDataFileType(typ):
            typ = typ.Upper()
            if typ.find("SIX") != -1:
                return "SIX"
            elif typ.find("SEVEN") != -1:
                return "SEVEN ELEVEN"
            elif typ.find("ADF") != -1:
                return "ADF & 3B"
            elif typ.find("3B") != -1:
                return "ADF & 3B"
            else:
                return "OXXO"

def fixDateValues(monthyValues):
    year = []
    column = monthyValues.columns.tolist()
    for month in column:
        year.append(month[-2:])
    res = list(OrderedDict.fromkeys(year))
    return res

# %%
class setUp():
    
    def __init__(self, db, typ):
        self.setActual = "Set Up"
        self.lineaActual = 1
        self.valor = " "
        self.db = db
        self.typ = typ
        
    def process(db):
        flag = True
        while flag:
            if typ == "ADF & 3B":
                return db
            elif typ == "SEVEN ELEVEN":
                firstRun = True
                for index, row in db.iterrows():
                    key = row['Plaza.1'] + str(row['COD BARRAS']) + str(row['año'])
                    if firstRun:
                        res = list(OrderedDict.fromkeys(db.mes))
                        ez = row['Retornabilidad'] + str(row['Envase']) + str(row['Mililitros Unidad'])
                        if row['Marca'] == 'GUINNESS':
                            row['Proveedor'] = 'DIAGEO'
                        if row['Marca'] == 'CARLSBERG':
                            row['Proveedor'] = 'CARLSBERG'
                        data = [row['año'], row['Plaza.1'], row['Marca'], row['Empaque'], ez, key, row['Proveedor']]
                        name = ['Year', 'GZ', 'Line Extension', 'Multipack', 'EZ', 'key', 'Proveedor']
                        for value in res:
                            data.append(0)
                            name.append(value)
                        df = pd.DataFrame(data, name).T
                        table = df
                        firstRun = False
                    try:
                        month = row['mes']
                        val = table['key'][table['key'] == key].index[0]
                        table.loc[table.index[val], month] = row['HTLS']
                    except:
                        ez = row['Retornabilidad'] + str(row['Envase']) + str(row['Mililitros Unidad'])
                        data = [row['año'], row['Plaza.1'], row['Marca'], row['Empaque'], ez, key, row['Proveedor']]
                        name = ['Year', 'GZ', 'Line Extension', 'Multipack', 'EZ', 'key', 'Proveedor']
                        for value in res:
                            data.append(0)
                            name.append(value)
                        df = pd.DataFrame(data, name).T
                        table = pd.concat([table, df], axis = 0, ignore_index=True)
                        month = row['mes']
                        val = table['key'][table['key'] == key].index[0]
                        table.loc[table.index[val], month] = row['HTLS']
            else:
                firstRun = True
                for index, row in db.iterrows():
                    key = row['OfV Description'] + str(row['SKU'])
                    if firstRun:
                        res = list(OrderedDict.fromkeys(db.Month))
                        ez = row['Returnability'] + row['Primary Pack Type'] + row['Primary Pack Group'] + row['HMex Pack Group'] + row['Pack Size']
                        data = [row['Year'], row['GZ Split TVN-VDM'], row['Line Extension'], row['Multipack'], ez, key]
                        name = ['Year', 'GZ', 'Line Extension', 'Multipack', 'EZ', 'key']
                        for value in res:
                            data.append(0)
                            name.append(value)
                        df = pd.DataFrame(data, name).T
                        table = df
                        firstRun = False
                try:
                    month = row['Month']
                    val = table['key'][table['key'] == key].index[0]
                    table.loc[table.index[val], month] = row['Value']
                except:
                    ez = row['Returnability'] + row['Primary Pack Type'] + row['Primary Pack Group'] + row['HMex Pack Group'] + row['Pack Size']
                    data = [row['Year'], row['GZ Split TVN-VDM'], row['Line Extension'], row['Multipack'], ez, key]
                    name = ['Year', 'GZ', 'Line Extension', 'Multipack', 'EZ', 'key']
                    for value in res:
                        data.append(0)
                        name.append(value)
                    df = pd.DataFrame(data, name).T
                    table = pd.concat([table, df], axis = 0, ignore_index=True)
                    month = row['Month']
                    val = table['key'][table['key'] == key].index[0]
                    table.loc[table.index[val], month] = row['Value']

        return table

# %%
class setCanal():
    
    def __init__(self, db, typ):
        self.setActual = "Unidades de Empaque"
        self.lineaActual = 1
        self.valor = " "
        self.canal = []
        self.canalInt = []
        self.canalMa = []
        self.db = db
        self.lenght = len(db)
        self.typ = typ
        
    def process(db):
        flag = True
        while flag:
            lineaActual = 1
            if typ == "SIX":
                try:
                    for x in range(lenght):
                        valor = x
                        canal.append('SIX')
                        canalInt.append('OFF TRAD')
                        canalMa.append('SIX / MODELORAMA')
                        lineaActual = lineaActual + 1
                    flag = False
                except:
                    flag = errorMessage(setActual, lineaActual, valor)
            elif typ == "SEVEN ELEVEN":
                try:
                    for x in range(lenght):
                        valor = x
                        canal.append('7 Eleven')
                        canalInt.append('Off Modern')
                        canalMa.append('OTHER -CS + PROX')
                        lineaActual = lineaActual + 1
                    flag = False
                except:
                    flag = errorMessage(setActual, lineaActual, valor)
            elif typ == "ADF & 3B":
                try:
                    for x in range(length):        
                        canal.append(db['Cliente Cadena'][x])
                        canalInt.append('Off Modern')
                        canalMa.append('OTHER -CS + PROX')
                        lineaActual = lineaActual + 1
                    flag = False
                except:
                    flag = errorMessage(setActual, lineaActual, valor)
                break;
            else:
                try:
                    for x in range(lenght):
                        valor = x
                        canal.append('SIX')
                        canalInt.append('OFF TRAD')
                        canalMa.append('SIX / MODELORAMA')
                    flag = False
                except:
                    flag = errorMessage(setActual, lineaActual, valor)
                    lineaActual = 1

        canal = pd.Series(canal)
        canalInt = pd.Series(canalInt)
        canalMa = pd.Series(canalMa)   
        return [canal, canalInt, canalMa]

# %%
class setUE():
    
    def __init__(self, db, typ):
        self.setActual = "Canal"
        self.lineaActual = 1
        self.valor = " "
        self.unidadesDeEmpaque = []
        self.db = db
        self.typ = typ
        
    def process(db):
        flag = True
        while flag:
            lineaActual = 1
            if typ == "ADF & 3B":
                try:
                    emCat = pd.read_excel('../Catalogs/CatalogoADFy3B.xlsx', sheet_name = 'Pack')
                    multipacks = db.Multipacks
                    for value in multipacks:
                        loc = emCat.loc[emCat.Multipacks == value]
                        unidadesDeEmpaque.append(loc['Val'].iloc[0])
                        lineaActual = lineaActual + 1  
                    flag = False
                except:
                    flag = errorMessage(setActual, lineaActual, valor)
            elif typ == "SEVEN ELEVEN":
                try:
                    unidadesDeEmpaque = db.Multipack
                    flag = False
                except:
                    flag = errorMessage(setActual, lineaActual, valor)
            else:
                try:
                    multipacks = db.Multipack
                    for value in multipacks:
                        valor = value
                        loc = [int(s) for s in value.split() if s.isdigit()]     
                        unidadesDeEmpaque.append(loc[0])
                        lineaActual = lineaActual + 1
                    flag = False
                    unidadesDeEmpaque = pd.Series(unidadesDeEmpaque) 
                except:
                    flag = errorMessage(setActual, lineaActual, valor)

        return [unidadesDeEmpaque]

# %%
class setGZ():
       
    def __init__(self, db):
        self.setActual = "GZ"
        self.lineaActual = 1
        self.valor = " "
        self.gz = db["GZ"]
        self.region = []
        self.gz1 = []
        self.fabricante = []
        
    def process(db):
        flag = True
        while flag:
            try:
                lineaActual = 1
                if typ == "ADF & 3B":
                    gzCat = pd.read_excel('../Catalogs/CatalogoADFy3B.xlsx', sheet_name = 'Gz')
                elif typ == "SEVEN ELEVEN":
                    gzCat = pd.read_excel('../Catalogs/CatalogoSevenEleven.xlsx', sheet_name = 'Gz')
                elif typ == "OXXO":
                    gzCat = pd.read_excel('../Catalogs/CatalogoOXXO.xlsx', sheet_name = 'Gz')
                else:
                    gzCat = pd.read_excel('../Catalogs/CatalogoSIX.xlsx', sheet_name = 'Gz') 

                for value in gz:
                    valor = value
                    loc = gzCat.loc[gzCat.Plaza == value]  
                    region.append(loc['REGION'].iloc[0])
                    gz1.append(loc['GZ'].iloc[0])
                    lineaActual = lineaActual + 1
                    region = pd.Series(region)
                    gz1 = pd.Series(gz1)
                flag = False
            except:
                flag = errorMessage(setActual, lineaActual, valor)
                lineaActual = 1
                
        return [region, gz1]

# %%
class setMarca():
    
    def __init__(self, db, typ):
        self.setActual = "Marca"
        self.lineaActual = 1
        self.valor = " "
        self.db = db
        self.typ = typ
        self.marca_hom = []
        self.ext_marca_hom = []
        self.diamante_precio_est = []
        self.tipo_liq_est = []
        self.liq = []
        self.marca_hom2 = []
        self.ext_marca_hom2 = []
        self.diamante_precio_hom = []
        self.manu = []
        self.priceTierCMI = []
        self.categoryCMI = []
        self.alcoholSegmentsCMI = []
        self.liquidSegmentsCMI = []
        self.brandCondition = []
        self.topLineSOg = []
        self.secSG = []
        self.fabricante = []
        
    def process(db):
        flag = True
        while flag:
            lineaActual = 1
            le = db['Line Extension']
            try: 
                if typ == "ADF & 3B":
                    marcaCat = pd.read_excel('', sheet_name = 'Marca')
                elif typ == "SEVEN ELEVEN":
                    marcaCat = pd.read_excel('', sheet_name = 'Marca')
                elif typ == "OXXO":
                    marcaCat = pd.read_excel('', sheet_name = 'Marca')
                else:
                    marcaCat = pd.read_excel('', sheet_name = 'Marca')           
                for value in le:    
                    valor = value
                    loc = marcaCat.loc[marcaCat['Line Extension'] == value]
                    marca_hom.append(loc['MARCA_HOM'].iloc[0])
                    ext_marca_hom.append(loc['EXT_MARCA_HOM'].iloc[0])
                    diamante_precio_est.append(loc['DIAMANTE_PRECIO_EST'].iloc[0])
                    tipo_liq_est.append(loc['TIPO_LIQ_EST'].iloc[0])
                    liq.append(loc['LIQ'].iloc[0])       
                    marca_hom2.append(loc['MARCA_HOM.1'].iloc[0])
                    ext_marca_hom2.append(loc['EXT_MARCA_HOM.1'].iloc[0])
                    diamante_precio_hom.append(loc['DIAMANTE_PRECIO_HOM'].iloc[0])
                    manu.append(loc['Manufacturer_CMI'].iloc[0])
                    if (loc['Manufacturer_CMI'].iloc[0]) == "HMEX":
                        fabricante.append("HEINEKEN")
                    elif (loc['Manufacturer_CMI'].iloc[0]) == "OTHER":
                        fabricante.append("OTHER")
                    else:
                        fabricante.append("ABI")
                    priceTierCMI.append(loc['Price_Tier_CMI'].iloc[0])
                    categoryCMI.append(loc['Category_CMI'].iloc[0])  
                    alcoholSegmentsCMI.append(loc['Alcohol_Segments_CMI'].iloc[0])
                    liquidSegmentsCMI.append(loc['Liquid_Segment_CMI'].iloc[0])
                    brandCondition.append(loc['BRAND_CONDITION'].iloc[0])
                    topLineSOg.append(loc['TOP LINE SOG (5 SOGS)'].iloc[0])
                    secSG.append(loc['Secondary_Source_of_Growth'].iloc[0])
                    lineaActual = lineaActual + 1
                flag = False
            except:
                flag = errorMessage(setActual, lineaActual, valor)
        marca_hom = pd.Series(marca_hom)
        ext_marca_hom = pd.Series(ext_marca_hom)
        diamante_precio_est = pd.Series(diamante_precio_est)
        tipo_liq_est = pd.Series(tipo_liq_est)
        liq = pd.Series(liq)
        marca_hom2 = pd.Series(marca_hom2)
        ext_marca_hom2 = pd.Series(ext_marca_hom2)
        diamante_precio_hom = pd.Series(diamante_precio_hom)
        manu = pd.Series(manu)
        priceTierCMI = pd.Series(priceTierCMI)
        categoryCMI = pd.Series(categoryCMI)
        alcoholSegmentsCMI = pd.Series(alcoholSegmentsCMI)
        liquidSegmentsCMI = pd.Series(liquidSegmentsCMI)
        brandCondition = pd.Series(brandCondition)
        topLineSOg = pd.Series(topLineSOg)
        secondarySOg = pd.Series(secSG)
        fabricante = pd.Series(fabricante)
        return [marca_hom, ext_marca_hom, diamante_precio_est, tipo_liq_est, liq, marca_hom2, ext_marca_hom2, diamante_precio_hom, manu, priceTierCMI,categoryCMI, alcoholSegmentsCMI, liquidSegmentsCMI, brandCondition, topLineSOg, secSG, fabricante]

# %%
class setReturnabiliy():
    
    def __init__(self, db, typ):
        self.setActual = "Returnability"
        self.lineaActual = 1
        self.valor = " "
        self.db = db
        self.typ = typ
        self.returnability = []
        self.packtypeHOM = []
        self.primaryPacktypeGroup = []
        self.groupPacksize = []
        self.packSizeHOM = []
        self.packtypeOk2 = []
        self.categorias = []
        self.packSize1Home = []
        self.pConcatenado1 = []
        self.pConcatenado2 = []
        self.presentacion = []
    
        
    def process(db):
        flag = True
        while flag:
            try: 
                if typ == "ADF & 3B":
                    marcaCat = pd.read_excel('', sheet_name = 'Returnability')
                    le = db['Presentación CCM']
                elif typ == "SEVEN ELEVEN":
                    marcaCat = pd.read_excel('', sheet_name = 'Returnability')
                    le = db['EZ']
                elif typ == "OXXO":
                    marcaCat = pd.read_excel('', sheet_name = 'Returnability')
                    le = db['EZ']
                else:
                    marcaCat = pd.read_excel('', sheet_name = 'Returnability')
                    le = db['EZ']
           
                for value in ez:   
                    valor = value
                    loc = returnabilityCat.loc[returnabilityCat['llave'] == value]
                    returnability.append(loc['Returnability'].iloc[0])
                    if loc['Returnability'].iloc[0] == 'Non Returnable':
                        presentacion.append('NO RETORNABLE')
                    else: 
                        presentacion.append('RETORNABLE')
                    packtypeHOM.append(loc['Packtype_HOM'].iloc[0])
                    primaryPacktypeGroup.append(loc['Primary_Packtype_Group'].iloc[0])
                    groupPacksize.append(loc['Group_Packsize'].iloc[0])
                    packSizeHOM.append(loc['Packsize_HOM'].iloc[0])
                    packtypeOk2.append(loc['PACKTYPE_OK_2'].iloc[0])
                    categorias.append(loc['Categorias'].iloc[0])
                    packSize1Home.append(loc['Packsize1_HOME'].iloc[0])
                    pConcatenado1.append(loc['Packsize_concatenado1'].iloc[0])
                    pConcatenado2.append(loc['Packsize_concatenado2'].iloc[0])
                    lineaActual = lineaActual + 1 
                    flag = False
            except:
                flag = errorMessage(setActual, lineaActual, valor)
        returnability  = pd.Series(returnability)
        packtypeHOM = pd.Series(packtypeHOM)
        primaryPacktypeGroup = pd.Series(primaryPacktypeGroup)
        groupPacksize = pd.Series(groupPacksize)
        packSizeHOM = pd.Series(packSizeHOM)
        packtypeOk2 = pd.Series(packtypeOk2)
        categorias = pd.Series(categorias)
        packSize1Home = pd.Series(packSize1Home)
        pConcatenado1 = pd.Series(pConcatenado1)
        pConcatenado2 = pd.Series(pConcatenado2)
        presentacion = pd.Series(presentacion)
        return [returnability, primaryPackType, primaryPackGroup, hMexPack, packSize, packtypeHOM, primaryPacktypeGroup, groupPacksize, packSizeHOM, packtypeOk2, categorias, packSize1Home, pConcatenado1, pConcatenado2, presentacion]

# %%
class generateTable():
    
    def __init__(self, db, valor, typ):
        self.setActual = "Table Generation"
        self.lineaActual = 1
        self.values = " "
        self.db = db
        self.valor = valor
        self.typ = typ
        
    def process(db):
        flag = True
        while flag:
            lineaActual = 1
            if typ == "ADF & 3B":
                añosPresentes = fixDateValues(db.iloc[:,9:])
                size = len(db)
                monthlyValues = g.columns.tolist()
                first = True
                first2 = True
                for value in añosPresentes:
                    años = []
                    for x in range(size):
                        años.append('20'+value)
                    años = pd.Series(años)
                    data = [años, valor[1], valor[0], valor[4], valor[5], valor[22], valor[6], valor[7], valor[8], valor[9], valor[10],  valor[33], valor[3], valor[2], valor[11], valor[12], valor[13], valor[23], valor[24], valor[25], valor[26], valor[27], valor[28], valor[29], valor[30], valor[31], valor[32], valor[14], valor[15], valor[16], valor[17], valor[18], valor[19], valor[20], valor[21]]
                    name = ['AÑO', 'CANAL INTEGRADO', 'CANAL', 'REGION', 'GZ', 'FABRICANTE', 'MARCA_EST', 'EXT_MARCA_EST', 'DIAMANTE_PRECIO_EST', 'TIPO_LIQ_EST', 'LIQ', 'PRESENTACION', 'UNIDADES_EMPAQUE', 'CANAL_MA', 'MARCA_HOM', 'EXT_MARCA_HOM', 'DIAMANTE_PRECIO_HOM', 'Retunability', 'Packtype_HOM', 'Primary_Packtype_Group', 'Group_Packsize', 'Packsize_HOM', 'PACKTYPE_OK_2', 'Categorias', 'Packsize1_HOME', 'Packsize_concatenado1', 'Packsize_concatenado2', 'Manufacturer_CMI', 'Price_Tier_CMI', 'Category_CMI', 'Alcohol_Segments_CMI', 'Liquid_Segment_CMI', 'BRAND_CONDITION', 'Primary_Source_of_Growth', 'Secondary_Source_of_Growth']
                    if first:
                        df = pd.DataFrame(data, name).T
                        table = df
                        first = False
                    else:
                        df = pd.DataFrame(data, name).T
                        table = pd.concat([table, df], axis = 0)
            else:
                try:
                    data = [db.Year, valor[1], valor[0], valor[4], valor[5], valor[22], valor[6], valor[7], valor[8], valor[9], valor[10],  valor[33], valor[3], valor[2], valor[11], valor[12], valor[13], valor[23], valor[24], valor[25], valor[26], valor[27], valor[28], valor[29], valor[30], valor[31], valor[32], valor[14], valor[15], valor[16], valor[17], valor[18], valor[19], valor[20], valor[21]]
                    name = ['AÑO', 'CANAL INTEGRADO', 'CANAL', 'REGION', 'GZ', 'FABRICANTE', 'MARCA_EST', 'EXT_MARCA_EST', 'DIAMANTE_PRECIO_EST', 'TIPO_LIQ_EST', 'LIQ', 'PRESENTACION', 'UNIDADES_EMPAQUE', 'CANAL_MA', 'MARCA_HOM', 'EXT_MARCA_HOM', 'DIAMANTE_PRECIO_HOM', 'Retunability', 'Packtype_HOM', 'Primary_Packtype_Group', 'Group_Packsize', 'Packsize_HOM', 'PACKTYPE_OK_2', 'Categorias', 'Packsize1_HOME', 'Packsize_concatenado1', 'Packsize_concatenado2', 'Manufacturer_CMI', 'Price_Tier_CMI', 'Category_CMI', 'Alcohol_Segments_CMI', 'Liquid_Segment_CMI', 'BRAND_CONDITION', 'Primary_Source_of_Growth', 'Secondary_Source_of_Growth']
                    g = db.iloc[:,7:]
                    monthlyValues = g.columns.tolist()
                    for month in monthlyValues:
                        data.append(db[month])
                        name.append(month)
                    df = pd.DataFrame(data, name).T
                    df.to_excel(typ + ".xlsx", index = False)
                except:
                    flag = errorMessage(setActual, lineaActual, values)

# %%
def setDataFileType(func):
    def _setDataFileType(*args, **kw):
        db = func(*args, **kw)[0]
        typ = func(*args, **kw)[1].upper()
        if typ.find("SIX") != -1:
            return db, "SIX"
        elif typ.find("SEVEN") != -1:
            return db, "SEVEN ELEVEN"
        elif typ.find("ADF") != -1:
            return db, "ADF & 3B"
        elif typ.find("3B") != -1:
            return db, "ADF & 3B"
        else:
            return "OXXO"
    return _setDataFileType


        
def databaseSetUP(func):
    def _databaseSetUP(*args, **kw):
        db = func(*args, **kw)[0]
        typ = func(*args, **kw)[1].upper()
        setActual = "Set Up"
        lineaActual = 1
        valor = " "
        flag = True
        while flag:
            if typ == "ADF & 3B":
                return db, typ
            elif typ == "SEVEN ELEVEN":
                firstRun = True
                for index, row in db.iterrows():
                    key = row['Plaza.1'] + str(row['COD BARRAS']) + str(row['año'])
                    if firstRun:
                        res = list(OrderedDict.fromkeys(db.mes))
                        ez = row['Retornabilidad'] + str(row['Envase']) + str(row['Mililitros Unidad'])
                        if row['Marca'] == 'GUINNESS':
                            row['Proveedor'] = 'DIAGEO'
                        if row['Marca'] == 'CARLSBERG':
                            row['Proveedor'] = 'CARLSBERG'
                        data = [row['año'], row['Plaza.1'], row['Marca'], row['Empaque'], ez, key, row['Proveedor']]
                        name = ['Year', 'GZ', 'Line Extension', 'Multipack', 'EZ', 'key', 'Proveedor']
                        for value in res:
                            data.append(0)
                            name.append(value)
                        df = pd.DataFrame(data, name).T
                        table = df
                        firstRun = False
                    try:
                        month = row['mes']
                        val = table['key'][table['key'] == key].index[0]
                        table.loc[table.index[val], month] = row['HTLS']
                    except:
                        ez = row['Retornabilidad'] + str(row['Envase']) + str(row['Mililitros Unidad'])
                        data = [row['año'], row['Plaza.1'], row['Marca'], row['Empaque'], ez, key, row['Proveedor']]
                        name = ['Year', 'GZ', 'Line Extension', 'Multipack', 'EZ', 'key', 'Proveedor']
                        for value in res:
                            data.append(0)
                            name.append(value)
                        df = pd.DataFrame(data, name).T
                        table = pd.concat([table, df], axis = 0, ignore_index=True)
                        month = row['mes']
                        val = table['key'][table['key'] == key].index[0]
                        table.loc[table.index[val], month] = row['HTLS']
            else:
                firstRun = True
                for index, row in db.iterrows():
                    key = row['OfV Description'] + str(row['SKU'])
                    if firstRun:
                        res = list(OrderedDict.fromkeys(db.Month))
                        ez = row['Returnability'] + row['Primary Pack Type'] + row['Primary Pack Group'] + row['HMex Pack Group'] + row['Pack Size']
                        data = [row['Year'], row['GZ Split TVN-VDM'], row['Line Extension'], row['Multipack'], ez, key]
                        name = ['Year', 'GZ', 'Line Extension', 'Multipack', 'EZ', 'key']
                        for value in res:
                            data.append(0)
                            name.append(value)
                        df = pd.DataFrame(data, name).T
                        table = df
                        firstRun = False
                try:
                    month = row['Month']
                    val = table['key'][table['key'] == key].index[0]
                    table.loc[table.index[val], month] = row['Value']
                except:
                    ez = row['Returnability'] + row['Primary Pack Type'] + row['Primary Pack Group'] + row['HMex Pack Group'] + row['Pack Size']
                    data = [row['Year'], row['GZ Split TVN-VDM'], row['Line Extension'], row['Multipack'], ez, key]
                    name = ['Year', 'GZ', 'Line Extension', 'Multipack', 'EZ', 'key']
                    for value in res:
                        data.append(0)
                        name.append(value)
                    df = pd.DataFrame(data, name).T
                    table = pd.concat([table, df], axis = 0, ignore_index=True)
                    month = row['Month']
                    val = table['key'][table['key'] == key].index[0]
                    table.loc[table.index[val], month] = row['Value']
        return table, typ
    return _databaseSetUP

def setCanal(func):
    def _setCanal(*args, **kw):
        db = func(*args, **kw)[0]
        typ = func(*args, **kw)[1]
        tablaFinal = []
        setActual = "Unidades de Empaque"
        valor = " "
        canal = []
        canalInt = []
        canalMa = []
        lenght = len(db)
        flag = True
        
        while flag:
            lineaActual = 1
            if typ == "SIX":
                try:
                    for x in range(lenght):
                        valor = x
                        canal.append('SIX')
                        canalInt.append('OFF TRAD')
                        canalMa.append('SIX / MODELORAMA')
                        lineaActual = lineaActual + 1
                    flag = False
                except:
                    flag = errorMessage(setActual, lineaActual, valor)
            elif typ == "SEVEN ELEVEN":
                try:
                    for x in range(lenght):
                        valor = x
                        canal.append('7 Eleven')
                        canalInt.append('Off Modern')
                        canalMa.append('OTHER -CS + PROX')
                        lineaActual = lineaActual + 1
                    flag = False
                except:
                    flag = errorMessage(setActual, lineaActual, valor)
            elif typ == "ADF & 3B":
                try:
                    for x in range(length):        
                        canal.append(db['Cliente Cadena'][x])
                        canalInt.append('Off Modern')
                        canalMa.append('OTHER -CS + PROX')
                        lineaActual = lineaActual + 1
                    flag = False
                except:
                    flag = errorMessage(setActual, lineaActual, valor)
                break;
            else:
                try:
                    for x in range(lenght):
                        valor = x
                        canal.append('SIX')
                        canalInt.append('OFF TRAD')
                        canalMa.append('SIX / MODELORAMA')
                    flag = False
                except:
                    flag = errorMessage(setActual, lineaActual, valor)

            canal = pd.Series(canal)
            canalInt = pd.Series(canalInt)
            canalMa = pd.Series(canalMa)
            tablaFinal.append(canal, canalInt, canalMa)
        return db, typ, tablaFinal
    return _setCanal

def setUE(func):
    def _setUE(*args, **kw):
        db = func(*args, **kw)[0]
        typ = func(*args, **kw)[1]
        tablaFinal = func(*args, **kw)[2]
        setActual = "Canal"
        valor = " "
        unidadesDeEmpaque = []
        flag = True
        
        while flag:
            lineaActual = 1
            if typ == "ADF & 3B":
                try:
                    emCat = pd.read_excel('', sheet_name = 'Pack')
                    multipacks = db.Multipacks
                    for value in multipacks:
                        loc = emCat.loc[emCat.Multipacks == value]
                        unidadesDeEmpaque.append(loc['Val'].iloc[0])
                        lineaActual = lineaActual + 1  
                    flag = False
                except:
                    flag = errorMessage(setActual, lineaActual, valor)
            elif typ == "SEVEN ELEVEN":
                try:
                    unidadesDeEmpaque = db.Multipack
                    flag = False
                except:
                    flag = errorMessage(setActual, lineaActual, valor)
            else:
                try:
                    multipacks = db.Multipack
                    for value in multipacks:
                        valor = value
                        loc = [int(s) for s in value.split() if s.isdigit()]     
                        unidadesDeEmpaque.append(loc[0])
                        lineaActual = lineaActual + 1
                    flag = False
                    unidadesDeEmpaque = pd.Series(unidadesDeEmpaque) 
                except:
                    flag = errorMessage(setActual, lineaActual, valor)
            tablaFinal.append(unidadesDeEmpaque)
        return db, typ, tablaFinal
    return _setUE

def setGZ(func):
    def _setGZ(*args, **kw):
        db = func(*args, **kw)[0]
        typ = func(*args, **kw)[1]
        tablaFinal = func(*args, **kw)[2]
        setActual = "GZ"
        valor = " "
        gz = db["GZ"]
        region = []
        gz1 = []
        GZ Split TVN-VDM
        flag = True
        while flag:
            try:
                lineaActual = 1
                if typ == "ADF & 3B":
                    gzCat = pd.read_excel('', sheet_name = 'Gz')
                elif typ == "SEVEN ELEVEN":
                    gzCat = pd.read_excel('', sheet_name = 'Gz')
                elif typ == "OXXO":
                    gzCat = pd.read_excel('', sheet_name = 'Gz')
                else:
                    gzCat = pd.read_excel('', sheet_name = 'Gz') 

                for value in gz:
                    valor = value
                    loc = gzCat.loc[gzCat.Plaza == value]  
                    region.append(loc['REGION'].iloc[0])
                    gz1.append(loc['GZ'].iloc[0])
                    lineaActual = lineaActual + 1
                    region = pd.Series(region)
                    gz1 = pd.Series(gz1)
                flag = False
            except:
                flag = errorMessage(setActual, lineaActual, valor)
            tablaFinal.append(region, gz1)
        return db, typ, tablaFinal    
    return _setGZ

def setMarca(func):
    def _setMarca(*args, **kw):
        db = func(*args, **kw)[0]
        typ = func(*args, **kw)[1]
        tablaFinal = func(*args, **kw)[2]
        setActual = "Marca"
        valor = " "
        marca_hom = []
        ext_marca_hom = []
        diamante_precio_est = []
        tipo_liq_est = []
        liq = []
        marca_hom2 = []
        ext_marca_hom2 = []
        diamante_precio_hom = []
        manu = []
        priceTierCMI = []
        categoryCMI = []
        alcoholSegmentsCMI = []
        liquidSegmentsCMI = []
        brandCondition = []
        topLineSOg = []
        secSG = []
        fabricante = []
        flag = True
        while flag:
            lineaActual = 1
            le = db['Line Extension']
            try: 
                if typ == "ADF & 3B":
                    marcaCat = pd.read_excel('', sheet_name = 'Marca')
                elif typ == "SEVEN ELEVEN":
                    marcaCat = pd.read_excel('', sheet_name = 'Marca')
                elif typ == "OXXO":
                    marcaCat = pd.read_excel('', sheet_name = 'Marca')
                else:
                    marcaCat = pd.read_excel('', sheet_name = 'Marca')           
                for value in le:    
                    valor = value
                    loc = marcaCat.loc[marcaCat['Line Extension'] == value]
                    marca_hom.append(loc['MARCA_HOM'].iloc[0])
                    ext_marca_hom.append(loc['EXT_MARCA_HOM'].iloc[0])
                    diamante_precio_est.append(loc['DIAMANTE_PRECIO_EST'].iloc[0])
                    tipo_liq_est.append(loc['TIPO_LIQ_EST'].iloc[0])
                    liq.append(loc['LIQ'].iloc[0])       
                    marca_hom2.append(loc['MARCA_HOM.1'].iloc[0])
                    ext_marca_hom2.append(loc['EXT_MARCA_HOM.1'].iloc[0])
                    diamante_precio_hom.append(loc['DIAMANTE_PRECIO_HOM'].iloc[0])
                    manu.append(loc['Manufacturer_CMI'].iloc[0])
                    if (loc['Manufacturer_CMI'].iloc[0]) == "HMEX":
                        fabricante.append("HEINEKEN")
                    elif (loc['Manufacturer_CMI'].iloc[0]) == "OTHER":
                        fabricante.append("OTHER")
                    else:
                        fabricante.append("ABI")
                    priceTierCMI.append(loc['Price_Tier_CMI'].iloc[0])
                    categoryCMI.append(loc['Category_CMI'].iloc[0])  
                    alcoholSegmentsCMI.append(loc['Alcohol_Segments_CMI'].iloc[0])
                    liquidSegmentsCMI.append(loc['Liquid_Segment_CMI'].iloc[0])
                    brandCondition.append(loc['BRAND_CONDITION'].iloc[0])
                    topLineSOg.append(loc['TOP LINE SOG (5 SOGS)'].iloc[0])
                    secSG.append(loc['Secondary_Source_of_Growth'].iloc[0])
                    lineaActual = lineaActual + 1
                flag = False
            except:
                flag = errorMessage(setActual, lineaActual, valor)
        marca_hom = pd.Series(marca_hom)
        ext_marca_hom = pd.Series(ext_marca_hom)
        diamante_precio_est = pd.Series(diamante_precio_est)
        tipo_liq_est = pd.Series(tipo_liq_est)
        liq = pd.Series(liq)
        marca_hom2 = pd.Series(marca_hom2)
        ext_marca_hom2 = pd.Series(ext_marca_hom2)
        diamante_precio_hom = pd.Series(diamante_precio_hom)
        manu = pd.Series(manu)
        priceTierCMI = pd.Series(priceTierCMI)
        categoryCMI = pd.Series(categoryCMI)
        alcoholSegmentsCMI = pd.Series(alcoholSegmentsCMI)
        liquidSegmentsCMI = pd.Series(liquidSegmentsCMI)
        brandCondition = pd.Series(brandCondition)
        topLineSOg = pd.Series(topLineSOg)
        secondarySOg = pd.Series(secSG)
        fabricante = pd.Series(fabricante)
        tablaFinal.append(marca_hom, ext_marca_hom, diamante_precio_est, tipo_liq_est, liq, marca_hom2, ext_marca_hom2, diamante_precio_hom, manu, priceTierCMI,categoryCMI, alcoholSegmentsCMI, liquidSegmentsCMI, brandCondition, topLineSOg, secSG, fabricante)
        return db, typ, tablaFinal    
    return _setMarca

def setReturnabiliy(func):
    def _setReturnability(*args, **kw):
        db = func(*args, **kw)[0]
        typ = func(*args, **kw)[1]
        tablaFinal = func(*args, **kw)[2]
        setActual = "Returnability"
        self.valor = " "
        self.returnability = []
        self.packtypeHOM = []
        self.primaryPacktypeGroup = []
        self.groupPacksize = []
        self.packSizeHOM = []
        self.packtypeOk2 = []
        self.categorias = []
        self.packSize1Home = []
        self.pConcatenado1 = []
        self.pConcatenado2 = []
        self.presentacion = []
        flag = True
        while flag:
            lineaActual = 1
            try: 
                if typ == "ADF & 3B":
                    marcaCat = pd.read_excel('', sheet_name = 'Returnability')
                    le = db['Presentación CCM']
                elif typ == "SEVEN ELEVEN":
                    marcaCat = pd.read_excel('', sheet_name = 'Returnability')
                    le = db['EZ']
                elif typ == "OXXO":
                    marcaCat = pd.read_excel('', sheet_name = 'Returnability')
                    le = db['EZ']
                else:
                    marcaCat = pd.read_excel('', sheet_name = 'Returnability')
                    le = db['EZ']
           
                for value in ez:   
                    valor = value
                    loc = returnabilityCat.loc[returnabilityCat['llave'] == value]
                    returnability.append(loc['Returnability'].iloc[0])
                    if loc['Returnability'].iloc[0] == 'Non Returnable':
                        presentacion.append('NO RETORNABLE')
                    else: 
                        presentacion.append('RETORNABLE')
                    packtypeHOM.append(loc['Packtype_HOM'].iloc[0])
                    primaryPacktypeGroup.append(loc['Primary_Packtype_Group'].iloc[0])
                    groupPacksize.append(loc['Group_Packsize'].iloc[0])
                    packSizeHOM.append(loc['Packsize_HOM'].iloc[0])
                    packtypeOk2.append(loc['PACKTYPE_OK_2'].iloc[0])
                    categorias.append(loc['Categorias'].iloc[0])
                    packSize1Home.append(loc['Packsize1_HOME'].iloc[0])
                    pConcatenado1.append(loc['Packsize_concatenado1'].iloc[0])
                    pConcatenado2.append(loc['Packsize_concatenado2'].iloc[0])
                    lineaActual = lineaActual + 1 
                    flag = False
            except:
                flag = errorMessage(setActual, lineaActual, valor)
        returnability  = pd.Series(returnability)
        packtypeHOM = pd.Series(packtypeHOM)
        primaryPacktypeGroup = pd.Series(primaryPacktypeGroup)
        groupPacksize = pd.Series(groupPacksize)
        packSizeHOM = pd.Series(packSizeHOM)
        packtypeOk2 = pd.Series(packtypeOk2)
        categorias = pd.Series(categorias)
        packSize1Home = pd.Series(packSize1Home)
        pConcatenado1 = pd.Series(pConcatenado1)
        pConcatenado2 = pd.Series(pConcatenado2)
        presentacion = pd.Series(presentacion)
        tablaFinal.append(returnability, primaryPackType, primaryPackGroup, hMexPack, packSize, packtypeHOM, primaryPacktypeGroup, groupPacksize, packSizeHOM, packtypeOk2, categorias, packSize1Home, pConcatenado1, pConcatenado2, presentacion)
        return db, typ, tablaFinal    
    return _setReturnability

def generateTable(func):
    def _generateTable(*args, **kw):
        db = func(*args, **kw)[0]
        typ = func(*args, **kw)[1]
        valor = func(*args, **kw)[2]
        self.setActual = "Table Generation"
        self.values = " "
        flag = True
        while flag:
            lineaActual = 1
            if typ == "ADF & 3B":
                añosPresentes = fixDateValues(db.iloc[:,9:])
                size = len(db)
                monthlyValues = g.columns.tolist()
                first = True
                first2 = True
                for value in añosPresentes:
                    años = []
                    for x in range(size):
                        años.append('20'+value)
                    años = pd.Series(años)
                    data = [años, valor[1], valor[0], valor[4], valor[5], valor[22], valor[6], valor[7], valor[8], valor[9], valor[10],  valor[33], valor[3], valor[2], valor[11], valor[12], valor[13], valor[23], valor[24], valor[25], valor[26], valor[27], valor[28], valor[29], valor[30], valor[31], valor[32], valor[14], valor[15], valor[16], valor[17], valor[18], valor[19], valor[20], valor[21]]
                    name = ['AÑO', 'CANAL INTEGRADO', 'CANAL', 'REGION', 'GZ', 'FABRICANTE', 'MARCA_EST', 'EXT_MARCA_EST', 'DIAMANTE_PRECIO_EST', 'TIPO_LIQ_EST', 'LIQ', 'PRESENTACION', 'UNIDADES_EMPAQUE', 'CANAL_MA', 'MARCA_HOM', 'EXT_MARCA_HOM', 'DIAMANTE_PRECIO_HOM', 'Retunability', 'Packtype_HOM', 'Primary_Packtype_Group', 'Group_Packsize', 'Packsize_HOM', 'PACKTYPE_OK_2', 'Categorias', 'Packsize1_HOME', 'Packsize_concatenado1', 'Packsize_concatenado2', 'Manufacturer_CMI', 'Price_Tier_CMI', 'Category_CMI', 'Alcohol_Segments_CMI', 'Liquid_Segment_CMI', 'BRAND_CONDITION', 'Primary_Source_of_Growth', 'Secondary_Source_of_Growth']
                    if first:
                        df = pd.DataFrame(data, name).T
                        table = df
                        first = False
                    else:
                        df = pd.DataFrame(data, name).T
                        table = pd.concat([table, df], axis = 0)
            else:
                try:
                    data = [db.Year, valor[1], valor[0], valor[4], valor[5], valor[22], valor[6], valor[7], valor[8], valor[9], valor[10],  valor[33], valor[3], valor[2], valor[11], valor[12], valor[13], valor[23], valor[24], valor[25], valor[26], valor[27], valor[28], valor[29], valor[30], valor[31], valor[32], valor[14], valor[15], valor[16], valor[17], valor[18], valor[19], valor[20], valor[21]]
                    name = ['AÑO', 'CANAL INTEGRADO', 'CANAL', 'REGION', 'GZ', 'FABRICANTE', 'MARCA_EST', 'EXT_MARCA_EST', 'DIAMANTE_PRECIO_EST', 'TIPO_LIQ_EST', 'LIQ', 'PRESENTACION', 'UNIDADES_EMPAQUE', 'CANAL_MA', 'MARCA_HOM', 'EXT_MARCA_HOM', 'DIAMANTE_PRECIO_HOM', 'Retunability', 'Packtype_HOM', 'Primary_Packtype_Group', 'Group_Packsize', 'Packsize_HOM', 'PACKTYPE_OK_2', 'Categorias', 'Packsize1_HOME', 'Packsize_concatenado1', 'Packsize_concatenado2', 'Manufacturer_CMI', 'Price_Tier_CMI', 'Category_CMI', 'Alcohol_Segments_CMI', 'Liquid_Segment_CMI', 'BRAND_CONDITION', 'Primary_Source_of_Growth', 'Secondary_Source_of_Growth']
                    g = db.iloc[:,7:]
                    monthlyValues = g.columns.tolist()
                    for month in monthlyValues:
                        data.append(db[month])
                        name.append(month)
                    df = pd.DataFrame(data, name).T
                    df.to_excel(typ + ".xlsx", index = False)
                except:
                    flag = errorMessage(setActual, lineaActual, values)
        return "La base de datos se compilo de manera exitosa"
    return _generateTable

class DatabaseGenerator:
    def __init__(self, db, typ):
        self.db, self.typ = openDataFile()
        print(typ)

    def openDataFile(self):
        entries = os.listdir("../Input/")
        i = 1
        for v in entries:
            print(str(i) + ". " + v)
            i = i + 1
        print("Seleccione el número del archivo: ")
        print("En caso de no tener el archivo en Input puede ingresar el directorio: ")
        aux = input()
        os.system("cls")
        if len(aux) <= 5:
            i = 1
            for v in entries:
                if aux == str(i):
                    return pd.read_excel("../Input/" + v), v
                i = i + 1
        else:
            return pd.read_excel(aux), v
    
    @generateTable
    @setReturnabiliy
    @setMarca
    @setGZ
    @setUE
    @setCanal
    @databaseSetUP
    @setDataFileType
    def generate(self):
        return self.db, self.typ

# %%
decorated_add = DatabaseGenerator(db, typ)
print(decorated_add.generate())
# Out:
# 1. InputADF&3B.xlsx
# 2. InputOxxo.xlsx
# 3. InputSIX.xlsx
# Seleccione el número del archivo:
# En caso de no tener el archivo en Input puede ingresar el directorio:
# 1
# InputSIX.xlsx
# ERROR
# Se ha detectado un valor inexistente en el Catalogo Unidades de Empaque
# Revisar en el documento de datos en la linea:  1
# El valor no registrado es:
# Favor de agregar el valor faltante a el catalago y volver a intentar
# Ingrese ENTER para continuar
# Ingrese cualquier otra tecla para salir
# 1
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "<ipython-input-80-c58309795e72>", line 138, in _setCanal
#     for x in range(length):
# NameError: name 'length' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-81-5af8b61c0375>", line 2, in <module>
#     print(decorated_add.generate())
#   File "<ipython-input-80-c58309795e72>", line 409, in _generateTable
#     db = func(*args, **kw)[0]
#   File "<ipython-input-80-c58309795e72>", line 338, in _setReturnability
#     db = func(*args, **kw)[0]
#   File "<ipython-input-80-c58309795e72>", line 251, in _setMarca
#     db = func(*args, **kw)[0]
#   File "<ipython-input-80-c58309795e72>", line 212, in _setGZ
#     db = func(*args, **kw)[0]
#   File "<ipython-input-80-c58309795e72>", line 167, in _setUE
#     db = func(*args, **kw)[0]
#   File "<ipython-input-80-c58309795e72>", line 145, in _setCanal
#     flag = errorMessage(setActual, lineaActual, valor)
#   File "<ipython-input-13-cc912c9bd046>", line 13, in errorMessage
#     sys.exit()
# SystemExit
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/opt/anaconda3/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-c58309795e72> in _setCanal(*args, **kw)
#     137                 try:
# --> 138                     for x in range(length):
#     139                         canal.append(db['Cliente Cadena'][x])
#
# NameError: name 'length' is not defined
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-81-5af8b61c0375> in <module>
#       1 decorated_add = DatabaseGenerator(db, typ)
# ----> 2 print(decorated_add.generate())
#
# <ipython-input-80-c58309795e72> in _generateTable(*args, **kw)
#     408     def _generateTable(*args, **kw):
# --> 409         db = func(*args, **kw)[0]
#     410         typ = func(*args, **kw)[1]
#
# <ipython-input-80-c58309795e72> in _setReturnability(*args, **kw)
#     337     def _setReturnability(*args, **kw):
# --> 338         db = func(*args, **kw)[0]
#     339         typ = func(*args, **kw)[1]
#
# <ipython-input-80-c58309795e72> in _setMarca(*args, **kw)
#     250     def _setMarca(*args, **kw):
# --> 251         db = func(*args, **kw)[0]
#     252         typ = func(*args, **kw)[1]
#
# <ipython-input-80-c58309795e72> in _setGZ(*args, **kw)
#     211     def _setGZ(*args, **kw):
# --> 212         db = func(*args, **kw)[0]
#     213         typ = func(*args, **kw)[1]
#
# <ipython-input-80-c58309795e72> in _setUE(*args, **kw)
#     166     def _setUE(*args, **kw):
# --> 167         db = func(*args, **kw)[0]
#     168         typ = func(*args, **kw)[1]
#
# <ipython-input-80-c58309795e72> in _setCanal(*args, **kw)
#     144                 except:
# --> 145                     flag = errorMessage(setActual, lineaActual, valor)
#     146                 break;
#
# <ipython-input-13-cc912c9bd046> in errorMessage(setActual, lineaActual, valor)
#      12     else:
# ---> 13         sys.exit()
#      14
#
# SystemExit:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2036                     stb = ['An exception has occurred, use %tb to see '
#    2037                            'the full traceback.\n']
# -> 2038                     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2039                                                                      value))
#    2040                 else:
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in get_exception_only(self, etype, value)
#     821         value : exception value
#     822         """
# --> 823         return ListTB.structured_traceback(self, etype, value)
#     824
#     825     def show_exception_only(self, etype, evalue):
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     696             chained_exceptions_tb_offset = 0
#     697             out_list = (
# --> 698                 self.structured_traceback(
#     699                     etype, evalue, (etb, chained_exc_ids),
#     700                     chained_exceptions_tb_offset, context)
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434         else:
#    1435             self.tb = tb
# -> 1436         return FormattedTB.structured_traceback(
#    1437             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1438
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334         if mode in self.verbose_modes:
#    1335             # Verbose modes need a full traceback
# -> 1336             return VerboseTB.structured_traceback(
#    1337                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1338             )
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191         """Return a nice text document describing the traceback."""
#    1192
# -> 1193         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1194                                                                tb_offset)
#    1195
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1149
#    1150
# -> 1151         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1152
#    1153         frames = self.format_records(records, last_unique, recursion_repeat)
#
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
import pandas as pd
import os
import sys
from collections import OrderedDict

# %%
b = "n"

# %%
b.upper()
# Out:
# 'N'

# %%
six = pd.read_excel('../Input/InputSIX.xlsx')

# %%
six
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6

# %%
def openDataFile():
    entries = os.listdir("../Input/")
    i = 1
    for v in entries:
        print(str(i) + ". " + v)
        i = i + 1
    print("Seleccione el número del archivo: ")
    print("En caso de no tener el archivo en Input puede ingresar el directorio: ")
    aux = input()
    os.system("cls")
    if len(aux) <= 5:
        i = 1
        for v in entries:
            if aux == str(i):
                return pd.read_excel("../Input/" + v), v
            i = i + 1
    else:
        return pd.read_excel(aux), v
